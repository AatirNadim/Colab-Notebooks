# %% [markdown]
# <a href="https://colab.research.google.com/github/AatirNadim/Colab-Notebooks/blob/main/Kaggle_Dataset_from_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/car data.csv')
df
# Out:
#     Car_Name  Year  Selling_Price  ...  Seller_Type  Transmission Owner
# 0       ritz  2014           3.35  ...       Dealer        Manual     0
# 1        sx4  2013           4.75  ...       Dealer        Manual     0
# 2       ciaz  2017           7.25  ...       Dealer        Manual     0
# 3    wagon r  2011           2.85  ...       Dealer        Manual     0
# 4      swift  2014           4.60  ...       Dealer        Manual     0
# ..       ...   ...            ...  ...          ...           ...   ...
# 296     city  2016           9.50  ...       Dealer        Manual     0
# 297     brio  2015           4.00  ...       Dealer        Manual     0
# 298     city  2009           3.35  ...       Dealer        Manual     0
# 299     city  2017          11.50  ...       Dealer        Manual     0
# 300     brio  2016           5.30  ...       Dealer        Manual     0
#
# [301 rows x 9 columns]

# %%
df['Owner'].astype(int).sum()
# Out:
# 13

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
plt.figure(figsize=(12,10))
plt.plot([i for i in range(0, len(df))], list(df['Selling_Price']), lw=1, color='#087E8B')
plt.plot([i for i in range(len(df))], list(df['Present_Price']), lw=1, color='red')
plt.show()

# %%
X=df.iloc[:,1:]

# %%
X=X.drop(columns=['Selling_Price'], axis=1)
X
# Out:
#      Year  Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission  Owner
# 0    2014           5.59       27000    Petrol      Dealer       Manual      0
# 1    2013           9.54       43000    Diesel      Dealer       Manual      0
# 2    2017           9.85        6900    Petrol      Dealer       Manual      0
# 3    2011           4.15        5200    Petrol      Dealer       Manual      0
# 4    2014           6.87       42450    Diesel      Dealer       Manual      0
# ..    ...            ...         ...       ...         ...          ...    ...
# 296  2016          11.60       33988    Diesel      Dealer       Manual      0
# 297  2015           5.90       60000    Petrol      Dealer       Manual      0
# 298  2009          11.00       87934    Petrol      Dealer       Manual      0
# 299  2017          12.50        9000    Diesel      Dealer       Manual      0
# 300  2016           5.90        5464    Petrol      Dealer       Manual      0
#
# [301 rows x 7 columns]

# %%
X['Fuel_Type'].value_counts()
# Out:
# Petrol    238
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64

# %%
X['Seller_Type'].value_counts().index
# Out:
# Index(['Dealer', 'Individual'], dtype='object')

# %%
X['Transmission'].value_counts()
# Out:
# Manual       260
# Automatic     40
# Name: Transmission, dtype: int64

# %%
X['Fuel_Type']=X['Fuel_Type'].map({'Petrol':0, 'Diesel':1, 'CNG':2})
X['Seller_Type']=X['Seller_Type'].map({'Dealer':0, 'Individual':1})
X['Transmission']=X['Transmission'].map({'Manual':0, 'Automatic':1})
X
# Out:
#      Year  Present_Price  Kms_Driven  ...  Seller_Type  Transmission  Owner
# 0    2014           5.59       27000  ...            0             0      0
# 1    2013           9.54       43000  ...            0             0      0
# 2    2017           9.85        6900  ...            0             0      0
# 3    2011           4.15        5200  ...            0             0      0
# 4    2014           6.87       42450  ...            0             0      0
# ..    ...            ...         ...  ...          ...           ...    ...
# 296  2016          11.60       33988  ...            0             0      0
# 297  2015           5.90       60000  ...            0             0      0
# 298  2009          11.00       87934  ...            0             0      0
# 299  2017          12.50        9000  ...            0             0      0
# 300  2016           5.90        5464  ...            0             0      0
#
# [301 rows x 7 columns]

# %%
X['Owner'].astype(int).sum()
# Out:
# 13

# %%
Y=df.iloc[:,2]
Y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
print(df['Seller_Type'].unique())
# Out:
# ['Dealer' 'Individual']

# %%
df['Owner'].unique()
# Out:
# array([0, 1, 3])

# %%
df.isna().any()
# Out:
# Car_Name         False
# Year             False
# Selling_Price    False
# Present_Price    False
# Kms_Driven       False
# Fuel_Type        False
# Seller_Type      False
# Transmission     False
# Owner            False
# dtype: bool

# %%
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
np.arange(0,100,100/len(df))
# Out:
# array([ 0.        ,  0.33222591,  0.66445183,  0.99667774,  1.32890365,
#         1.66112957,  1.99335548,  2.3255814 ,  2.65780731,  2.99003322,
#         3.32225914,  3.65448505,  3.98671096,  4.31893688,  4.65116279,
#         4.9833887 ,  5.31561462,  5.64784053,  5.98006645,  6.31229236,
#         6.64451827,  6.97674419,  7.3089701 ,  7.64119601,  7.97342193,
#         8.30564784,  8.63787375,  8.97009967,  9.30232558,  9.6345515 ,
#         9.96677741, 10.29900332, 10.63122924, 10.96345515, 11.29568106,
#        11.62790698, 11.96013289, 12.2923588 , 12.62458472, 12.95681063,
#        13.28903654, 13.62126246, 13.95348837, 14.28571429, 14.6179402 ,
#        14.95016611, 15.28239203, 15.61461794, 15.94684385, 16.27906977,
#        16.61129568, 16.94352159, 17.27574751, 17.60797342, 17.94019934,
#        18.27242525, 18.60465116, 18.93687708, 19.26910299, 19.6013289 ,
#        19.93355482, 20.26578073, 20.59800664, 20.93023256, 21.26245847,
# ...

# %%
df['current_year']=list(np.arange(0,100,100/len(df)))

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  ...  Transmission  Owner current_year
# 0       ritz  2014           3.35  ...        Manual      0     0.000000
# 1        sx4  2013           4.75  ...        Manual      0     0.332226
# 2       ciaz  2017           7.25  ...        Manual      0     0.664452
# 3    wagon r  2011           2.85  ...        Manual      0     0.996678
# 4      swift  2014           4.60  ...        Manual      0     1.328904
# ..       ...   ...            ...  ...           ...    ...          ...
# 296     city  2016           9.50  ...        Manual      0    98.338870
# 297     brio  2015           4.00  ...        Manual      0    98.671096
# 298     city  2009           3.35  ...        Manual      0    99.003322
# 299     city  2017          11.50  ...        Manual      0    99.335548
# 300     brio  2016           5.30  ...        Manual      0    99.667774
#
# [301 rows x 10 columns]

# %%
df['Year'].map((lambda x: 2020-x))
# Out:
# 0       6
# 1       7
# 2       3
# 3       9
# 4       6
#        ..
# 296     4
# 297     5
# 298    11
# 299     3
# 300     4
# Name: Year, Length: 301, dtype: int64

# %%
X['Year']=X['Year'].map((lambda x:2020-x))
X
# Out:
#      Year  Present_Price  Kms_Driven  ...  Seller_Type  Transmission  Owner
# 0       6           5.59       27000  ...            0             0      0
# 1       7           9.54       43000  ...            0             0      0
# 2       3           9.85        6900  ...            0             0      0
# 3       9           4.15        5200  ...            0             0      0
# 4       6           6.87       42450  ...            0             0      0
# ..    ...            ...         ...  ...          ...           ...    ...
# 296     4          11.60       33988  ...            0             0      0
# 297     5           5.90       60000  ...            0             0      0
# 298    11          11.00       87934  ...            0             0      0
# 299     3          12.50        9000  ...            0             0      0
# 300     4           5.90        5464  ...            0             0      0
#
# [301 rows x 7 columns]

# %%
df.drop(columns=['current_year'], axis=1, inplace=True)

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  ...  Seller_Type  Transmission Owner
# 0       ritz  2014           3.35  ...       Dealer        Manual     0
# 1        sx4  2013           4.75  ...       Dealer        Manual     0
# 2       ciaz  2017           7.25  ...       Dealer        Manual     0
# 3    wagon r  2011           2.85  ...       Dealer        Manual     0
# 4      swift  2014           4.60  ...       Dealer        Manual     0
# ..       ...   ...            ...  ...          ...           ...   ...
# 296     city  2016           9.50  ...       Dealer        Manual     0
# 297     brio  2015           4.00  ...       Dealer        Manual     0
# 298     city  2009           3.35  ...       Dealer        Manual     0
# 299     city  2017          11.50  ...       Dealer        Manual     0
# 300     brio  2016           5.30  ...       Dealer        Manual     0
#
# [301 rows x 9 columns]

# %%
df
# Out:
#      Year  Selling_Price  ...  Seller_Type_Individual  Transmission_Manual
# 0    2014           3.35  ...                       0                    1
# 1    2013           4.75  ...                       0                    1
# 2    2017           7.25  ...                       0                    1
# 3    2011           2.85  ...                       0                    1
# 4    2014           4.60  ...                       0                    1
# ..    ...            ...  ...                     ...                  ...
# 296  2016           9.50  ...                       0                    1
# 297  2015           4.00  ...                       0                    1
# 298  2009           3.35  ...                       0                    1
# 299  2017          11.50  ...                       0                    1
# 300  2016           5.30  ...                       0                    1
#
# [301 rows x 106 columns]

# %%
df1=df.drop(columns=['Car_Name'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-85c41f5b8fa7> in <module>()
# ----> 1 df1=df.drop(columns=['Car_Name'], axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...

# %%
# Out:
#      Year  Selling_Price  ...  Seller_Type_Individual  Transmission_Manual
# 0    2014           3.35  ...                       0                    1
# 1    2013           4.75  ...                       0                    1
# 2    2017           7.25  ...                       0                    1
# 3    2011           2.85  ...                       0                    1
# 4    2014           4.60  ...                       0                    1
# ..    ...            ...  ...                     ...                  ...
# 296  2016           9.50  ...                       0                    1
# 297  2015           4.00  ...                       0                    1
# 298  2009           3.35  ...                       0                    1
# 299  2017          11.50  ...                       0                    1
# 300  2016           5.30  ...                       0                    1
#
# [301 rows x 106 columns]

# %%
X
# Out:
#      Year  Present_Price  Kms_Driven  ...  Seller_Type  Transmission  Owner
# 0       6           5.59       27000  ...            0             0      0
# 1       7           9.54       43000  ...            0             0      0
# 2       3           9.85        6900  ...            0             0      0
# 3       9           4.15        5200  ...            0             0      0
# 4       6           6.87       42450  ...            0             0      0
# ..    ...            ...         ...  ...          ...           ...    ...
# 296     4          11.60       33988  ...            0             0      0
# 297     5           5.90       60000  ...            0             0      0
# 298    11          11.00       87934  ...            0             0      0
# 299     3          12.50        9000  ...            0             0      0
# 300     4           5.90        5464  ...            0             0      0
#
# [301 rows x 7 columns]
